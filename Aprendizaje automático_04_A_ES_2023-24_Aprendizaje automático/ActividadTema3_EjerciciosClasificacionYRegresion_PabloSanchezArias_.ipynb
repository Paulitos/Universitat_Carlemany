# %% [markdown]
# · Ejercicio: consideramos las siguientes características de algoritmos. Para cada afirmación o
# sentencia, indicar si corresponde a un algoritmo de Clasificación o Regresión
# 1. En el problema a resolver, las variables objetivo o dependientes son discretas
# 2. El resultado del modelo son valores continuos
# 3. El objetivo es predecir categorías o etiquetas de clases
# 4. Ejemplos de estos modelos son: predicción del precio de una acción en bolsa; predecir
# el precio de un inmueble; predecir la cantidad de demanda de un producto
# 5. A este grupo pertenecen las regresiones lineales y no-lineales
#
# **Respuesta:**
# 1. Clasificación: En la clasificación, las variables objetivo o dependientes representan categorías o clases discretas a las que se asignan los datos.
# 2. Regresión: En la regresión, el resultado del modelo consiste en valores continuos, ya que se trata de predecir una cantidad numérica en lugar de una categoría.
# 3. Clasificación: La previsión de categorías o etiquetas de clases es el objetivo principal de los algoritmos de clasificación.
# 4. Regresión: Los ejemplos proporcionados (predicción del precio de una acción en bolsa, precio de un inmueble y cantidad de demanda de un producto) son típicos de problemas de regresión, donde se busca predecir un valor numérico continuo.
# 5. Regresión: Tanto las regresiones lineales como las no lineales son técnicas de modelado utilizadas en problemas de regresión, donde se predice un valor numérico en función de otras variables.

# %% [markdown]
# · Ejercicio: consideramos el siguiente algoritmo en Python que implementa el modelo de aprendizaje
# automático k-NN visto en el Tema 3. El programa nos muestra los resultados del modelo k-NN con
# un número de parámetros n_neighbors creciente. Es decir, podemos observar en el gráfico la
# precisión de los modelos ajustados, a medida que aumentamos la complejidad del algoritmo (más
# parámetros n_neighbors)
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# from sklearn.model_selection import train_test_split
# from sklearn.datasets import load_breast_cancer
# from sklearn.neighbors import KNeighborsClassifier
#
# cancer = load_breast_cancer()
# X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state = 66)
# training_accuracy = []
# test_accuracy = []
#
# # Probar varios modelos con n neighbors-vecinos
# neighbors_settings = range(1, 11)
# for n_neighbors in neighbors_settings:
#     # Construimos el modelo k-NN
#     clf = KNeighborsClassifier(n_neighbors = n_neighbors)
#     clf.fit(X_train, y_train)
#     # Precisión del modelo en datos train
#     training_accuracy.append(clf.score(X_train, y_train))
#     # Precisión del modelo en datos test
#     test_accuracy.append(clf.score(X_test, y_test))
#
# plt.plot(neighbors_settings, training_accuracy, label = "Precisión con datos train")
# plt.plot(neighbors_settings, test_accuracy, label = "Precisión con datos test")
# plt.ylabel("Precisión del modelo k-NN")
# plt.xlabel("n-neighbors")
# plt.legend()
# ```
#
# Comentar estos resultados. ¿Los modelos generalizan mejor a mayor complejidad?
# Explicar brevemente
#
# **Respuesta:**
#
# En este ejercicio, exploramos cómo varía la precisión del modelo k-Nearest Neighbors (k-NN) a medida que ajustamos el parámetro K (n_neighbors). Utilizamos el conjunto de datos de cáncer de mama de Scikit-Learn y evaluamos la precisión del modelo en los conjuntos de entrenamiento y prueba para diferentes valores de K.
#
# Al analizar el gráfico resultante, podemos observar claramente cómo la precisión del modelo varía con respecto a K. La precisión en los datos de entrenamiento tiende a disminuir a medida que K aumenta, mientras que la precisión en los datos de prueba alcanza su punto máximo alrededor de **K = 6** y luego disminuye para valores de K mayores.
#
# Este comportamiento sugiere que para valores de K más altos, el modelo está sobreajustado **(overfitting)** a los datos de entrenamiento. En otras palabras, el modelo se adapta demasiado a los detalles específicos de los datos de entrenamiento y no generaliza bien a nuevos datos. Esto se refleja en la disminución de la precisión en los datos de prueba.
#
# En contraste, para valores más bajos de K, el modelo puede no capturar patrones importantes en los datos y, por lo tanto, también muestra una menor precisión en los datos de prueba.
#
# Por lo tanto, el gráfico nos ayuda a identificar un valor óptimo de K alrededor de 6, donde el modelo generaliza bien sin sobreajustarse ni subajustarse. Esto demuestra la importancia de seleccionar cuidadosamente el valor de K para obtener un modelo k-NN efectivo y evitar problemas de sobreajuste.
#
# En resumen, este ejercicio ilustra cómo ajustar el parámetro K en k-NN y cómo el sobreajuste puede afectar la precisión del modelo en datos de prueba. Se destaca la importancia de encontrar un equilibrio adecuado en la elección de K para lograr un rendimiento óptimo en un problema de clasificación.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
from sklearn.neighbors import KNeighborsClassifier

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state = 66)
training_accuracy = []
test_accuracy = []

# Probar varios modelos con n neighbors-vecinos
neighbors_settings = range(1, 11)
for n_neighbors in neighbors_settings:
    # Construimos el modelo k-NN
    clf = KNeighborsClassifier(n_neighbors = n_neighbors)
    clf.fit(X_train, y_train)
    # Precisión del modelo en datos train
    training_accuracy.append(clf.score(X_train, y_train))
    # Precisión del modelo en datos test
    test_accuracy.append(clf.score(X_test, y_test))

plt.plot(neighbors_settings, training_accuracy, label = "Precisión con datos train")
plt.plot(neighbors_settings, test_accuracy, label = "Precisión con datos test")
plt.ylabel("Precisión del modelo k-NN")
plt.xlabel("n-neighbors")
plt.legend()
